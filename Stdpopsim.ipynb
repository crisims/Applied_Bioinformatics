# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/CRISTINA DÍAZ UBIETA/Bioinformática/2nd year/Applied Bioinformatics/Google_Colab

# %%
#@title StdPopSim
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-testresources is already the newest version (2.0.0-2).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libgsl-dev' instead of 'libgsl0-dev'
# python-dev is already the newest version (2.7.15~rc1-1).
# libgsl-dev is already the newest version (2.4+dfsg-6).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# ...

# %%
#Importing packages and installing depencencies etc for stdpopsim
# !sudo apt install python3-testresources
# !sudo apt-get install python-dev libgsl0-dev
# !python -m pip install stdpopsim

# %%
#Running the stdpopsim. You need to manually change chromosome for each run
# !stdpopsim DroMel -c chrX -g ComeronCrossover_dm6 -o DroMCCX.ts -d African3Epoch_1S16  4
#Converting the ts file into a vcf file
# !tskit vcf DroMCCX.ts > DroMCCX.vcf
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/usr/local/lib/python3.6/dist-packages/stdpopsim/cli.py", line 58, in format
#     record.args = (match.group(1),)
# AttributeError: 'NoneType' object has no attribute 'group'
# Call stack:
#   File "/usr/local/bin/stdpopsim", line 8, in <module>
#     sys.exit(stdpopsim_main())
#   File "/usr/local/lib/python3.6/dist-packages/stdpopsim/cli.py", line 651, in stdpopsim_main
#     run(args)
#   File "/usr/local/lib/python3.6/dist-packages/stdpopsim/cli.py", line 642, in run
#     args.runner(args)
#   File "/usr/local/lib/python3.6/dist-packages/stdpopsim/cli.py", line 436, in run_simulation
#     length_multiplier=args.length_multiplier)
# ...
